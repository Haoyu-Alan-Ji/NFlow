# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd
import normflows as nf
import time
from torch.distributions import Normal

torch.manual_seed(123)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class NBase(nn.Module):
    def __init__(self, dim, init_loc=0.0, init_log_scale=-2.5):
        super().__init__()
        self.dim = dim
        self.loc = nn.Parameter(torch.full((dim,), float(init_loc)))
        self.raw_log_scale = nn.Parameter(torch.full((dim,), float(init_log_scale)))

    def log_scale(self):
        return torch.clamp(self.raw_log_scale, min=-5.0, max=2.0)

    def scale(self):
        return torch.exp(self.log_scale())

    def rsample(self, num_samples):
        eta = torch.randn(
            num_samples,
            self.dim,
            device=self.loc.device,
            dtype=self.loc.dtype,
        )
        z0 = self.loc.unsqueeze(0) + self.scale().unsqueeze(0) * eta
        return eta, z0

    def log_prob(self, z0):
        log_scale = self.log_scale().unsqueeze(0)
        var = torch.exp(2.0 * log_scale)
        return -0.5 * (
            ((z0 - self.loc.unsqueeze(0)) ** 2) / var
            + 2.0 * log_scale
            + math.log(2.0 * math.pi)
        ).sum(dim=1)

# %%
def simfun1(n=180, p=100, seed=123, snr=3.0, true_prop=0.1, device=None, dtype=torch.float32,):

    rng = np.random.default_rng(seed)
    torch.manual_seed(seed)

    X = rng.standard_normal((n, p)).astype(np.float32)
    X = (X - X.mean(axis=0, keepdims=True)) / (X.std(axis=0, keepdims=True) + 1e-8)

    n_active = int(p * true_prop)
    active_idx = np.sort(rng.choice(p, size=n_active, replace=False))

    beta_true = np.zeros(p, dtype=np.float32)
    magnitudes = rng.uniform(0.3, 2.0, size=n_active).astype(np.float32)
    signs = rng.choice([-1.0, 1.0], size=n_active).astype(np.float32)
    beta_true[active_idx] = signs * magnitudes

    signal = X @ beta_true
    sigma2 = np.var(signal) / snr
    sigma = np.sqrt(sigma2)

    y = signal + sigma * rng.standard_normal(n).astype(np.float32)
    y = y - y.mean()

    X_t = torch.tensor(X, dtype=dtype, device=device)
    y_t = torch.tensor(y, dtype=dtype, device=device)
    beta_true_t = torch.tensor(beta_true, dtype=dtype, device=device)

    info = {"n": n, "p": p, "n_active": n_active, "sigma2": float(sigma2), "sigma": float(sigma), "active_idx": active_idx, "snr": snr,}

    return X_t, y_t, beta_true_t, info

# %%
class AffineCoupling(nn.Module):
    def __init__(self, dim, mask, hidden_units=128, num_hidden_layers=2, scale_clip=2.0):
        super().__init__()
        self.dim = dim
        self.register_buffer("mask", mask.view(1, dim))
        self.scale_clip = float(scale_clip)

        widths = [dim] + [hidden_units] * num_hidden_layers + [dim]
        self.s_net = nf.nets.MLP(widths, init_zeros=True)
        self.t_net = nf.nets.MLP(widths, init_zeros=True)

    def forward(self, x, return_logdet=False):
        x_masked = x * self.mask

        raw_log_scale = self.s_net(x_masked) * (1.0 - self.mask)
        shift = self.t_net(x_masked) * (1.0 - self.mask)

        log_scale = self.scale_clip * torch.tanh(raw_log_scale / self.scale_clip)
        y = x_masked + (1.0 - self.mask) * (x * torch.exp(log_scale) + shift)

        if return_logdet:
            logdet = log_scale.sum(dim=-1)
            return y, logdet
        return y

    def inverse(self, y, return_logdet=False):
        y_masked = y * self.mask

        raw_log_scale = self.s_net(y_masked) * (1.0 - self.mask)
        shift = self.t_net(y_masked) * (1.0 - self.mask)

        log_scale = self.scale_clip * torch.tanh(raw_log_scale / self.scale_clip)
        x = y_masked + (1.0 - self.mask) * ((y - shift) * torch.exp(-log_scale))

        if return_logdet:
            logdet = (-log_scale).sum(dim=-1)
            return x, logdet
        return x


class FlowMap(nn.Module):
    def __init__(self, dim, K=4, hidden_units=128, num_hidden_layers=2, scale_clip=2.0):
        super().__init__()
        self.dim = dim

        base_mask = torch.tensor(
            [1.0 if i % 2 == 0 else 0.0 for i in range(dim)],
            dtype=torch.float32,
        )

        layers = []
        for k in range(K):
            mask = base_mask if (k % 2 == 0) else (1.0 - base_mask)
            layers.append(
                AffineCoupling(
                    dim=dim,
                    mask=mask,
                    hidden_units=hidden_units,
                    num_hidden_layers=num_hidden_layers,
                    scale_clip=scale_clip,
                )
            )

        self.layers = nn.ModuleList(layers)

    def forward(self, x, return_logdet=False):
        z = x
        if return_logdet:
            total_logdet = x.new_zeros(x.shape[0])

        for layer in self.layers:
            if return_logdet:
                z, logdet = layer(z, return_logdet=True)
                total_logdet = total_logdet + logdet
            else:
                z = layer(z)

        if return_logdet:
            return z, total_logdet
        return z

    def inverse(self, z, return_logdet=False):
        x = z
        if return_logdet:
            total_logdet = z.new_zeros(z.shape[0])

        for layer in reversed(self.layers):
            if return_logdet:
                x, logdet = layer.inverse(x, return_logdet=True)
                total_logdet = total_logdet + logdet
            else:
                x = layer.inverse(x)

        if return_logdet:
            return x, total_logdet
        return x

# %%
class Relaxedsas(nn.Module):
    def __init__(
        self,
        X,
        y,
        sigma2,
        tau,
        g_theta,
        penalty_type="none",
        support_target=None,
    ):
        super().__init__()
        if g_theta is None:
            raise ValueError("g_theta must be provided.")

        self.register_buffer("X", X)
        self.register_buffer("y", y)
        self.register_buffer("sigma2", torch.tensor(float(sigma2), dtype=X.dtype, device=X.device))
        self.register_buffer("tau", torch.tensor(float(tau), dtype=X.dtype, device=X.device))

        self.n, self.p = X.shape
        self.dim = 2 * self.p + 1
        self.g_theta = g_theta

        self.penalty_type = penalty_type
        self.support_target = support_target

    def set_tau(self, tau):
        self.tau.fill_(float(tau))

    def decode(self, eps):
        xi = self.g_theta(eps)

        p = self.p
        s = xi[:, :p]
        u = xi[:, p:2 * p]
        t = xi[:, 2 * p:2 * p + 1]

        gate = torch.sigmoid((u - t) / self.tau)
        beta = s * gate

        return {
            "eps": eps,
            "xi": xi,
            "s": s,
            "u": u,
            "t": t,
            "gate": gate,
            "beta": beta,
        }

    def penalty(self, dec):
        gate = dec["gate"]                      # [B, p]
        soft_support = gate.sum(dim=1)         # [B]

        if self.penalty_type == "none":
            pen = torch.zeros_like(soft_support)

        elif self.penalty_type == "support_l1":
            pen = soft_support

        elif self.penalty_type == "support_target":
            if self.support_target is None:
                raise ValueError("support_target must be provided for support_target penalty.")
            target = torch.as_tensor(
                float(self.support_target),
                dtype=soft_support.dtype,
                device=soft_support.device,
            )
            pen = (soft_support - target).pow(2)

        else:
            raise ValueError(f"Unknown penalty_type: {self.penalty_type}")

        return pen

    def log_joint(self, eps):
        dec = self.decode(eps)
        beta = dec["beta"]

        fit = self.X @ beta.T
        resid = self.y[:, None] - fit

        loglik = -0.5 * (
            resid.pow(2).sum(dim=0) / self.sigma2
            + self.n * torch.log(2.0 * torch.pi * self.sigma2)
        )

        log_p0_eps = -0.5 * (
            eps.pow(2) + math.log(2.0 * math.pi)
        ).sum(dim=1)

        return loglik + log_p0_eps

# %%
class FlowVI(nn.Module):
    def __init__(self, q0, posterior_flow, generative_model):
        super().__init__()
        self.q0 = q0
        self.posterior_flow = posterior_flow
        self.generative_model = generative_model

    def sample_posterior(self, num_samples):
        _, z0 = self.q0.rsample(num_samples)
        eps, logdet = self.posterior_flow(z0, return_logdet=True)
        log_q_eps = self.q0.log_prob(z0) - logdet
        return eps, log_q_eps

    def neg_elbo(self, num_samples=256, elbo_beta=1.0, penalty_weight=0.0, return_parts=False):
        eps, log_q_eps = self.sample_posterior(num_samples)

        log_joint = self.generative_model.log_joint(eps)
        dec = self.generative_model.decode(eps)
        penalty = self.generative_model.penalty(dec)

        base_obj = (log_q_eps - elbo_beta * log_joint).mean()
        penalty_mean = penalty.mean()
        total = base_obj + penalty_weight * penalty_mean

        if return_parts:
            return {
                "loss": total,
                "base_obj": base_obj.detach(),
                "penalty": penalty_mean.detach(),
                "soft_support_mean": dec["gate"].sum(dim=1).mean().detach(),
            }

        return total


def build_flow_vi(
    X,
    y,
    sigma2,
    tau,
    K_q=8,
    K_g=8,
    hidden_units=64,
    num_hidden_layers=2,
    penalty_type="none",
    support_target=None,
):
    dim = 2 * X.shape[1] + 1

    g_theta = FlowMap(
        dim=dim,
        K=K_g,
        hidden_units=hidden_units,
        num_hidden_layers=num_hidden_layers,
        scale_clip=2.0,
    )

    generative_model = Relaxedsas(
        X=X,
        y=y,
        sigma2=sigma2,
        tau=tau,
        g_theta=g_theta,
        penalty_type=penalty_type,
        support_target=support_target,
    )

    q0 = NBase(dim=dim, init_loc=0.0, init_log_scale=-2.5)

    posterior_flow = FlowMap(
        dim=dim,
        K=K_q,
        hidden_units=hidden_units,
        num_hidden_layers=num_hidden_layers,
        scale_clip=2.0,
    )

    return FlowVI(q0=q0, posterior_flow=posterior_flow, generative_model=generative_model)

# %%
def train_flow(
    model,
    epochs=1000,
    num_samples=128,
    lr=5e-5,
    tau_start=1.0,
    tau_end=0.05,
    anneal_ratio=0.7,
    grad_clip=3.0,
    print_every=100,
    elbo_beta=1.0,
    pip_R=2000,
    penalty_weight=0.0,
):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    losses = []
    tau_hist = []
    grad_hist = []
    penalty_hist = []
    soft_support_hist = []
    expected_support_hist = []
    suspect_hist = []

    anneal_epochs = max(1, int(round(epochs * anneal_ratio)))

    for epoch in range(1, epochs + 1):
        model.train()
        optimizer.zero_grad(set_to_none=True)

        if epoch <= anneal_epochs:
            frac = (epoch - 1) / max(anneal_epochs - 1, 1)
            tau_now = tau_start * (tau_end / tau_start) ** frac
        else:
            tau_now = float(tau_end)

        model.generative_model.set_tau(tau_now)
        tau_hist.append(float(tau_now))

        out = model.neg_elbo(
            num_samples=num_samples,
            elbo_beta=elbo_beta,
            penalty_weight=penalty_weight,
            return_parts=True,
        )
        loss = out["loss"]
        loss.backward()

        if grad_clip is not None:
            grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            grad_norm = float(grad_norm)
        else:
            grad_norm = 0.0

        optimizer.step()

        losses.append(float(loss.item()))
        grad_hist.append(grad_norm)
        penalty_hist.append(float(out["penalty"].item()))
        soft_support_hist.append(float(out["soft_support_mean"].item()))

        draws = sample_posterior_latents(model, R=pip_R)
        u = draws["u"]
        t = draws["t"]
        if t.ndim == 1:
            t = t.unsqueeze(1)

        pip = (u > t).float().mean(dim=0)
        expected_support = float(pip.sum().item())
        suspect_num = int(((pip > 0.3) & (pip < 0.7)).sum().item())

        expected_support_hist.append(expected_support)
        suspect_hist.append(suspect_num)

        if epoch % print_every == 0 or epoch == 1:
            print(
                f"[epoch {epoch:04d}] "
                f"loss={loss.item():.6f} "
                f"tau={tau_now:.6f} "
                f"grad_norm={grad_norm:.6f} "
                f"penalty={out['penalty'].item():.6f} "
                f"soft_support={out['soft_support_mean'].item():.3f} "
                f"expected_select={expected_support:.3f} "
                f"suspect_number={suspect_num}"
            )

    return (
        losses,
        tau_hist,
        grad_hist,
        penalty_hist,
        soft_support_hist,
        expected_support_hist,
        suspect_hist,
    )

# %%
@torch.no_grad()
def sample_posterior_latents(model, R=2000):
    model.eval()

    q0 = model.q0
    _, z0 = q0.rsample(R)               # [R, d]
    eps, _ = model.posterior_flow(z0, return_logdet=True)
    dec = model.generative_model.decode(eps)

    out = {
        "s": dec["s"].detach().cpu(),          # [R, p]
        "u": dec["u"].detach().cpu(),          # [R, p]
        "t": dec["t"].detach().cpu(),          # [R, 1] or [R]
        "beta": dec["beta"].detach().cpu(),    # [R, p]
    }
    return out

@torch.no_grad()
def pip_summary(model, beta_true=None, R=2000, c=0.5):
    draws = sample_posterior_latents(model, R=R)

    s = draws["s"]
    u = draws["u"]                      # [R, p]
    t = draws["t"]
    beta = draws["beta"]

    if t.ndim == 1:
        t = t.unsqueeze(1)              # [R, 1]

    ind = (u > t).int()                 # [R, p]
    pip = ind.float().mean(dim=0)       # [p]
    beta_soft_mean = beta.mean(dim=0)        # [p]
    beta_hard_mean = (s * ind.float()).mean(dim=0)

    support_c = (pip > c).int().numpy()

    df = pd.DataFrame({
    "j": np.arange(pip.numel()),
    "pip": pip.numpy(),
    "beta_hard_mean": beta_hard_mean.numpy(),
    "beta_soft_mean": beta_soft_mean.numpy(),
    "selected_c": support_c,
})

    metrics = {
        "R": R,
        "pip_threshold": c,
        "expected_support_size": float(pip.sum().item()),
        "n_selected_at_c": int(support_c.sum()),
        "selected_idx_at_c": np.where(support_c == 1)[0].tolist(),
    }

    if beta_true is not None:
        beta_true_cpu = beta_true.detach().cpu()
        truth = (beta_true_cpu.abs() > 1e-12).int().numpy()
        pred = support_c

        tp = int(((pred == 1) & (truth == 1)).sum())
        fp = int(((pred == 1) & (truth == 0)).sum())
        fn = int(((pred == 0) & (truth == 1)).sum())
        tn = int(((pred == 0) & (truth == 0)).sum())

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

        df["beta_true"] = beta_true_cpu.numpy()
        df["truth"] = truth
        df["pred_c"] = pred

        metrics.update({
            "tp": tp, "fp": fp, "fn": fn, "tn": tn,
            "precision": precision,
            "recall": recall,
            "f1": f1,
        })

    return df, metrics, draws

# %%
def simflow(
    seed=123,
    device=None,
    dtype=torch.float32,
    hidden_units=64,
    num_hidden_layers=2,
    anneal_ratio=1.0,
    n=180,
    p=100,
    snr=3.0,
    true_prop=0.1,
    tau_end=0.5,
    K_q=8,
    K_g=8,
    epochs=1000,
    num_samples=128,
    lr=5e-5,
    grad_clip=3.0,
    print_every=100,
    pip_R=2000,
    pip_c=0.5,
    penalty_type="none",
    penalty_weight=0.0,
    support_target=None,
):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    X, y, beta_true, sim_info = simfun1(
        n=n,
        p=p,
        seed=seed,
        snr=snr,
        true_prop=true_prop,
        device=device,
        dtype=dtype,
    )

    print("===== Simulation info =====")
    print(sim_info)

    if penalty_type == "support_target" and support_target is None:
        support_target = int(round(true_prop * p))

    model = build_flow_vi(
        X=X,
        y=y,
        sigma2=sim_info["sigma2"],
        tau=tau_end,
        K_q=K_q,
        K_g=K_g,
        hidden_units=hidden_units,
        num_hidden_layers=num_hidden_layers,
        penalty_type=penalty_type,
        support_target=support_target,
    ).to(device)

    losses, tau_hist, grad_hist, penalty_hist, soft_support_hist, expected_support_hist, suspect_hist = train_flow(
        model=model,
        epochs=epochs,
        num_samples=num_samples,
        lr=lr,
        tau_start=1.0,
        tau_end=tau_end,
        anneal_ratio=anneal_ratio,
        grad_clip=grad_clip,
        print_every=print_every,
        elbo_beta=1.0,
        pip_R=pip_R,
        penalty_weight=penalty_weight,
    )

    pip_df, pip_metrics, posterior_draws = pip_summary(
        model,
        beta_true=beta_true,
        R=pip_R,
        c=pip_c,
    )

    out = {
        "beta_true": beta_true,
        "sim_info": sim_info,
        "model": model,
        "losses": losses,
        "tau_hist": tau_hist,
        "grad_hist": grad_hist,
        "penalty_hist": penalty_hist,
        "soft_support_hist": soft_support_hist,
        "expected_support_hist": expected_support_hist,
        "suspect_hist": suspect_hist,
        "pip_df": pip_df,
        "pip_metrics": pip_metrics,
        "posterior_draws": posterior_draws,
        "config": {
            "penalty_type": penalty_type,
            "penalty_weight": penalty_weight,
            "support_target": support_target,
            "tau_end": tau_end,
            "anneal_ratio": anneal_ratio,
            "K_q": K_q,
            "K_g": K_g,
            "epochs": epochs,
            "num_samples": num_samples,
            "lr": lr,
            "pip_R": pip_R,
            "pip_c": pip_c,
        },
    }

    return out

def show_simflow_results(out, top_k=20, sort_by="pip"):
    sim_info = out["sim_info"]
    pip_df = out["pip_df"].copy()
    pip_metrics = out["pip_metrics"]
    config = out.get("config", {})

    print("===== Simulation info =====")
    print({
        "n": sim_info["n"],
        "p": sim_info["p"],
        "n_active": sim_info["n_active"],
        "snr": sim_info["snr"],
        "active_idx": sim_info["active_idx"].tolist() if hasattr(sim_info["active_idx"], "tolist") else sim_info["active_idx"],
    })

    if config:
        print("\n===== Training / penalty config =====")
        print({
            "penalty_type": config.get("penalty_type", None),
            "penalty_weight": config.get("penalty_weight", None),
            "support_target": config.get("support_target", None),
            "tau_end": config.get("tau_end", None),
            "anneal_ratio": config.get("anneal_ratio", None),
        })

    print("\n===== Variational PIP summary =====")
    print({
        "R": pip_metrics["R"],
        "pip_threshold": pip_metrics["pip_threshold"],
        "expected_support_size": pip_metrics["expected_support_size"],
        "n_selected_at_c": pip_metrics["n_selected_at_c"],
        "selected_idx_at_c": pip_metrics["selected_idx_at_c"],
    })

    if "precision" in pip_metrics:
        print("\n===== Selection metrics at threshold c =====")
        print({
            "tp": pip_metrics["tp"],
            "fp": pip_metrics["fp"],
            "fn": pip_metrics["fn"],
            "tn": pip_metrics["tn"],
            "precision": pip_metrics["precision"],
            "recall": pip_metrics["recall"],
            "f1": pip_metrics["f1"],
        })

    true_active = set(sim_info["active_idx"].tolist()) if hasattr(sim_info["active_idx"], "tolist") else set(sim_info["active_idx"])
    pip_df["is_true_active"] = pip_df["j"].isin(true_active)

    if sort_by not in pip_df.columns:
        raise ValueError(f"sort_by='{sort_by}' not found in pip_df columns: {list(pip_df.columns)}")

    view_cols = [c for c in [
        "j", "pip", "pip_uncertainty", "beta_hard_mean", "is_true_active", "beta_true"
    ] if c in pip_df.columns]

    top_df = pip_df.sort_values(sort_by, ascending=False).head(top_k)[view_cols]

    print(f"\n===== Top {top_k} variables by {sort_by} =====")
    print(top_df.to_string(index=False))

    return top_df

# %%
out_flow0 = simflow(
    seed=123,
    n=120,
    p=100,
    snr=2.5,
    true_prop=0.1,
    pip_R=100,
    pip_c=0.9,
    tau_end=0.05,
    anneal_ratio=1,
    K_q=16,
    K_g=16,
    hidden_units=64,
    num_hidden_layers=2,
    epochs=6000,
    num_samples=128,
    lr=5e-5,
    grad_clip=3.0,
    print_every=100,
    penalty_type="none",
    penalty_weight=0.0,
)

top_df0 = show_simflow_results(out_flow0, top_k=20, sort_by="pip")
# Out:
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'sigma2': 6.834272766113282, 'sigma': 2.614244205523516, 'active_idx': array([14, 23, 24, 28, 29, 45, 69, 74, 84, 90], dtype=int64), 'snr': 2.5}
# [epoch 0001] loss=891.764465 tau=1.000000 grad_norm=275.459290 penalty=0.000000 soft_support=50.136 expected_select=45.930 suspect_number=100
# [epoch 0100] loss=654.215271 tau=0.951764 grad_norm=188.912216 penalty=0.000000 soft_support=70.752 expected_select=87.880 suspect_number=7
# [epoch 0200] loss=378.606750 tau=0.905403 grad_norm=116.416542 penalty=0.000000 soft_support=32.091 expected_select=18.670 suspect_number=16
# [epoch 0300] loss=288.756958 tau=0.861300 grad_norm=107.831612 penalty=0.000000 soft_support=26.200 expected_select=11.680 suspect_number=6
# [epoch 0400] loss=262.748901 tau=0.819346 grad_norm=72.142227 penalty=0.000000 soft_support=23.862 expected_select=8.320 suspect_number=0
# [epoch 0500] loss=253.806839 tau=0.779435 grad_norm=81.545258 penalty=0.000000 soft_support=22.664 expected_select=7.420 suspect_number=1
# [epoch 0600] loss=249.853561 tau=0.741468 grad_norm=74.167755 penalty=0.000000 soft_support=22.204 expected_select=7.310 suspect_number=1
# [epoch 0700] loss=248.626892 tau=0.705350 grad_norm=55.507950 penalty=0.000000 soft_support=21.839 expected_select=7.230 suspect_number=0
# [epoch 0800] loss=246.023163 tau=0.670992 grad_norm=61.839294 penalty=0.000000 soft_support=21.249 expected_select=7.010 suspect_number=0
# [epoch 0900] loss=245.551971 tau=0.638307 grad_norm=64.882797 penalty=0.000000 soft_support=21.123 expected_select=6.910 suspect_number=0
# [epoch 1000] loss=244.854065 tau=0.607215 grad_norm=73.068565 penalty=0.000000 soft_support=20.565 expected_select=6.810 suspect_number=0
# [epoch 1100] loss=244.654541 tau=0.577637 grad_norm=72.168274 penalty=0.000000 soft_support=20.710 expected_select=6.910 suspect_number=0
# [epoch 1200] loss=244.202698 tau=0.549500 grad_norm=62.181824 penalty=0.000000 soft_support=20.414 expected_select=6.880 suspect_number=0
# [epoch 1300] loss=243.838348 tau=0.522733 grad_norm=67.394768 penalty=0.000000 soft_support=20.422 expected_select=6.970 suspect_number=0
# [epoch 1400] loss=243.808273 tau=0.497270 grad_norm=56.984013 penalty=0.000000 soft_support=20.774 expected_select=7.020 suspect_number=0
# [epoch 1500] loss=243.501038 tau=0.473048 grad_norm=69.462105 penalty=0.000000 soft_support=20.598 expected_select=7.120 suspect_number=0
# [epoch 1600] loss=243.666351 tau=0.450005 grad_norm=106.011940 penalty=0.000000 soft_support=21.502 expected_select=7.360 suspect_number=1
# [epoch 1700] loss=243.302704 tau=0.428085 grad_norm=61.671867 penalty=0.000000 soft_support=22.168 expected_select=7.640 suspect_number=1
# [epoch 1800] loss=243.357758 tau=0.407233 grad_norm=72.198555 penalty=0.000000 soft_support=21.460 expected_select=7.410 suspect_number=1
# [epoch 1900] loss=243.259018 tau=0.387396 grad_norm=78.887619 penalty=0.000000 soft_support=21.485 expected_select=7.470 suspect_number=1
# [epoch 2000] loss=243.399536 tau=0.368526 grad_norm=83.568954 penalty=0.000000 soft_support=21.564 expected_select=7.700 suspect_number=1
# [epoch 2100] loss=243.262039 tau=0.350575 grad_norm=62.952484 penalty=0.000000 soft_support=22.129 expected_select=7.790 suspect_number=0
# [epoch 2200] loss=242.933670 tau=0.333498 grad_norm=72.570908 penalty=0.000000 soft_support=21.982 expected_select=7.890 suspect_number=0
# [epoch 2300] loss=243.073486 tau=0.317253 grad_norm=144.436188 penalty=0.000000 soft_support=23.040 expected_select=8.340 suspect_number=0
# [epoch 2400] loss=243.214539 tau=0.301799 grad_norm=129.956482 penalty=0.000000 soft_support=23.601 expected_select=8.630 suspect_number=0
# [epoch 2500] loss=243.106842 tau=0.287098 grad_norm=144.176834 penalty=0.000000 soft_support=23.626 expected_select=9.030 suspect_number=2
# [epoch 2600] loss=243.105545 tau=0.273114 grad_norm=143.262543 penalty=0.000000 soft_support=23.944 expected_select=9.760 suspect_number=2
# [epoch 2700] loss=243.135223 tau=0.259810 grad_norm=133.088669 penalty=0.000000 soft_support=24.613 expected_select=10.610 suspect_number=0
# [epoch 2800] loss=243.020325 tau=0.247154 grad_norm=117.524933 penalty=0.000000 soft_support=25.077 expected_select=10.990 suspect_number=0
# [epoch 2900] loss=243.144455 tau=0.235115 grad_norm=97.138321 penalty=0.000000 soft_support=25.891 expected_select=11.100 suspect_number=0
# [epoch 3000] loss=243.017349 tau=0.223663 grad_norm=82.099838 penalty=0.000000 soft_support=26.244 expected_select=11.330 suspect_number=0
# [epoch 3100] loss=243.141144 tau=0.212768 grad_norm=62.205257 penalty=0.000000 soft_support=26.256 expected_select=11.530 suspect_number=1
# [epoch 3200] loss=242.914139 tau=0.202404 grad_norm=89.438339 penalty=0.000000 soft_support=26.088 expected_select=11.380 suspect_number=1
# [epoch 3300] loss=242.990967 tau=0.192544 grad_norm=83.704102 penalty=0.000000 soft_support=26.074 expected_select=11.690 suspect_number=1
# [epoch 3400] loss=243.050079 tau=0.183165 grad_norm=85.834724 penalty=0.000000 soft_support=26.286 expected_select=11.780 suspect_number=1
# [epoch 3500] loss=242.908981 tau=0.174243 grad_norm=99.714668 penalty=0.000000 soft_support=26.333 expected_select=12.120 suspect_number=0
# [epoch 3600] loss=242.811615 tau=0.165756 grad_norm=107.702591 penalty=0.000000 soft_support=26.553 expected_select=12.810 suspect_number=1
# [epoch 3700] loss=242.858841 tau=0.157682 grad_norm=96.834175 penalty=0.000000 soft_support=26.814 expected_select=13.070 suspect_number=0
# [epoch 3800] loss=242.919357 tau=0.150001 grad_norm=105.427292 penalty=0.000000 soft_support=27.028 expected_select=13.190 suspect_number=0
# [epoch 3900] loss=242.826859 tau=0.142694 grad_norm=234.414337 penalty=0.000000 soft_support=27.959 expected_select=14.950 suspect_number=2
# [epoch 4000] loss=242.909744 tau=0.135743 grad_norm=241.602646 penalty=0.000000 soft_support=28.143 expected_select=16.240 suspect_number=3
# [epoch 4100] loss=242.773743 tau=0.129131 grad_norm=255.839523 penalty=0.000000 soft_support=28.383 expected_select=17.680 suspect_number=2
# [epoch 4200] loss=242.794769 tau=0.122841 grad_norm=244.460587 penalty=0.000000 soft_support=28.843 expected_select=18.710 suspect_number=0
# [epoch 4300] loss=242.787933 tau=0.116858 grad_norm=259.234070 penalty=0.000000 soft_support=29.141 expected_select=19.030 suspect_number=0
# [epoch 4400] loss=242.830643 tau=0.111165 grad_norm=258.646027 penalty=0.000000 soft_support=29.393 expected_select=19.910 suspect_number=1
# [epoch 4500] loss=242.833740 tau=0.105750 grad_norm=266.118530 penalty=0.000000 soft_support=30.050 expected_select=20.520 suspect_number=1
# [epoch 4600] loss=242.749100 tau=0.100599 grad_norm=283.141144 penalty=0.000000 soft_support=30.321 expected_select=20.740 suspect_number=1
# [epoch 4700] loss=242.802002 tau=0.095699 grad_norm=281.576324 penalty=0.000000 soft_support=30.774 expected_select=21.180 suspect_number=2
# [epoch 4800] loss=242.693344 tau=0.091037 grad_norm=299.569763 penalty=0.000000 soft_support=31.306 expected_select=21.570 suspect_number=0
# [epoch 4900] loss=242.792694 tau=0.086603 grad_norm=209.570953 penalty=0.000000 soft_support=32.421 expected_select=21.980 suspect_number=0
# [epoch 5000] loss=242.886856 tau=0.082384 grad_norm=191.911057 penalty=0.000000 soft_support=34.588 expected_select=22.910 suspect_number=2
# [epoch 5100] loss=242.786285 tau=0.078371 grad_norm=211.053101 penalty=0.000000 soft_support=35.426 expected_select=24.800 suspect_number=2
# [epoch 5200] loss=242.791092 tau=0.074554 grad_norm=217.894699 penalty=0.000000 soft_support=35.386 expected_select=24.740 suspect_number=2
# [epoch 5300] loss=242.676987 tau=0.070922 grad_norm=227.202316 penalty=0.000000 soft_support=35.671 expected_select=25.320 suspect_number=3
# [epoch 5400] loss=242.772614 tau=0.067468 grad_norm=218.444489 penalty=0.000000 soft_support=35.983 expected_select=26.380 suspect_number=2
# [epoch 5500] loss=242.840302 tau=0.064181 grad_norm=237.554077 penalty=0.000000 soft_support=36.316 expected_select=28.200 suspect_number=3
# [epoch 5600] loss=242.750076 tau=0.061055 grad_norm=285.849884 penalty=0.000000 soft_support=36.624 expected_select=29.020 suspect_number=1
# [epoch 5700] loss=242.657700 tau=0.058081 grad_norm=280.141205 penalty=0.000000 soft_support=37.133 expected_select=30.570 suspect_number=0
# [epoch 5800] loss=242.695679 tau=0.055252 grad_norm=301.760773 penalty=0.000000 soft_support=37.483 expected_select=31.210 suspect_number=1
# [epoch 5900] loss=242.795044 tau=0.052560 grad_norm=318.257965 penalty=0.000000 soft_support=37.782 expected_select=31.850 suspect_number=1
# [epoch 6000] loss=242.738266 tau=0.050000 grad_norm=312.797150 penalty=0.000000 soft_support=38.250 expected_select=33.010 suspect_number=0
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'snr': 2.5, 'active_idx': [14, 23, 24, 28, 29, 45, 69, 74, 84, 90]}
#
# ===== Training / penalty config =====
# {'penalty_type': 'none', 'penalty_weight': 0.0, 'support_target': None, 'tau_end': 0.05, 'anneal_ratio': 1}
#
# ===== Variational PIP summary =====
# {'R': 100, 'pip_threshold': 0.9, 'expected_support_size': 32.880001068115234, 'n_selected_at_c': 33, 'selected_idx_at_c': [4, 5, 7, 10, 11, 14, 15, 16, 17, 23, 24, 28, 29, 30, 32, 33, 37, 39, 45, 47, 49, 55, 56, 57, 64, 69, 71, 75, 77, 86, 87, 90, 93]}
#
# ===== Selection metrics at threshold c =====
# {'tp': 8, 'fp': 25, 'fn': 2, 'tn': 65, 'precision': 0.24242424242424243, 'recall': 0.8, 'f1': 0.372093023255814}
#
# ===== Top 20 variables by pip =====
#  j  pip  beta_hard_mean  is_true_active  beta_true
# 64  1.0        1.167268           False   0.000000
# 30  1.0        1.272168           False   0.000000
# 87  1.0       -0.727821           False   0.000000
# 23  1.0       -0.940567            True  -1.340611
# 24  1.0       -0.726109            True  -0.703405
# 86  1.0       -1.472806           False   0.000000
# 28  1.0       -2.510059            True  -1.759511
# 29  1.0        1.491424            True   0.670153
# 49  1.0       -0.081991           False   0.000000
# 90  1.0       -1.393849            True  -1.979678
# 32  1.0        2.083190           False   0.000000
# 33  1.0       -0.855070           False   0.000000
# 47  1.0       -1.100506           False   0.000000
# 37  1.0       -1.426022           False   0.000000
# 45  1.0        0.571321            True   1.536880
# 39  1.0       -0.849248           False   0.000000
# 69  1.0        1.228347            True   0.941051
# 77  1.0        0.693025           False   0.000000
# 56  1.0        1.030161           False   0.000000
# 17  1.0        0.715827           False   0.000000

# %%
out_flow1 = simflow(
    seed=123,
    n=120,
    p=100,
    snr=2.5,
    true_prop=0.1,
    pip_R=100,
    pip_c=0.9,
    tau_end=0.05,
    anneal_ratio=1,
    K_q=16,
    K_g=16,
    hidden_units=64,
    num_hidden_layers=2,
    epochs=6000,
    num_samples=128,
    lr=5e-5,
    grad_clip=3.0,
    print_every=100,
    penalty_type="support_l1",
    penalty_weight=1e-3, 
)

top_df1 = show_simflow_results(out_flow1, top_k=20, sort_by="pip")
# Out:
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'sigma2': 6.834272766113282, 'sigma': 2.614244205523516, 'active_idx': array([14, 23, 24, 28, 29, 45, 69, 74, 84, 90], dtype=int64), 'snr': 2.5}
# [epoch 0001] loss=891.814575 tau=1.000000 grad_norm=275.461639 penalty=50.135815 soft_support=50.136 expected_select=45.930 suspect_number=100
# [epoch 0100] loss=654.306152 tau=0.951764 grad_norm=188.944229 penalty=70.664398 soft_support=70.664 expected_select=87.780 suspect_number=7
# [epoch 0200] loss=378.627655 tau=0.905403 grad_norm=116.145035 penalty=31.922947 soft_support=31.923 expected_select=18.440 suspect_number=15
# [epoch 0300] loss=288.677277 tau=0.861300 grad_norm=92.199341 penalty=26.053055 soft_support=26.053 expected_select=11.440 suspect_number=6
# [epoch 0400] loss=262.868408 tau=0.819346 grad_norm=70.666222 penalty=23.392090 soft_support=23.392 expected_select=8.100 suspect_number=0
# [epoch 0500] loss=253.908234 tau=0.779435 grad_norm=89.672424 penalty=22.641405 soft_support=22.641 expected_select=8.280 suspect_number=1
# [epoch 0600] loss=249.932404 tau=0.741468 grad_norm=80.377213 penalty=21.949278 soft_support=21.949 expected_select=7.970 suspect_number=0
# [epoch 0700] loss=248.570129 tau=0.705350 grad_norm=52.975281 penalty=21.329056 soft_support=21.329 expected_select=7.740 suspect_number=1
# [epoch 0800] loss=246.027084 tau=0.670992 grad_norm=77.794067 penalty=20.689651 soft_support=20.690 expected_select=7.380 suspect_number=0
# [epoch 0900] loss=245.494919 tau=0.638307 grad_norm=77.696266 penalty=20.041359 soft_support=20.041 expected_select=7.160 suspect_number=0
# [epoch 1000] loss=244.893845 tau=0.607215 grad_norm=76.690376 penalty=19.529366 soft_support=19.529 expected_select=7.110 suspect_number=0
# [epoch 1100] loss=244.646698 tau=0.577637 grad_norm=148.058624 penalty=19.441732 soft_support=19.442 expected_select=7.130 suspect_number=0
# [epoch 1200] loss=244.502777 tau=0.549500 grad_norm=102.829689 penalty=19.277159 soft_support=19.277 expected_select=7.110 suspect_number=0
# [epoch 1300] loss=243.965744 tau=0.522733 grad_norm=78.053726 penalty=19.594025 soft_support=19.594 expected_select=7.180 suspect_number=0
# [epoch 1400] loss=243.980743 tau=0.497270 grad_norm=116.489334 penalty=19.463221 soft_support=19.463 expected_select=7.180 suspect_number=0
# [epoch 1500] loss=243.729767 tau=0.473048 grad_norm=142.897705 penalty=19.011059 soft_support=19.011 expected_select=7.160 suspect_number=0
# [epoch 1600] loss=243.829880 tau=0.450005 grad_norm=143.085968 penalty=19.138212 soft_support=19.138 expected_select=7.130 suspect_number=0
# [epoch 1700] loss=243.403702 tau=0.428085 grad_norm=144.851105 penalty=19.085836 soft_support=19.086 expected_select=7.250 suspect_number=0
# [epoch 1800] loss=243.514893 tau=0.407233 grad_norm=132.193039 penalty=19.001354 soft_support=19.001 expected_select=7.280 suspect_number=0
# [epoch 1900] loss=243.453247 tau=0.387396 grad_norm=115.159203 penalty=19.655960 soft_support=19.656 expected_select=7.510 suspect_number=1
# [epoch 2000] loss=243.658890 tau=0.368526 grad_norm=75.608154 penalty=19.664669 soft_support=19.665 expected_select=7.720 suspect_number=1
# [epoch 2100] loss=243.378799 tau=0.350575 grad_norm=81.035408 penalty=19.084906 soft_support=19.085 expected_select=7.350 suspect_number=1
# [epoch 2200] loss=242.968475 tau=0.333498 grad_norm=140.526077 penalty=19.652914 soft_support=19.653 expected_select=7.690 suspect_number=1
# [epoch 2300] loss=243.190979 tau=0.317253 grad_norm=154.374084 penalty=19.525471 soft_support=19.525 expected_select=7.530 suspect_number=1
# [epoch 2400] loss=243.317871 tau=0.301799 grad_norm=168.849365 penalty=19.674124 soft_support=19.674 expected_select=7.610 suspect_number=1
# [epoch 2500] loss=243.184250 tau=0.287098 grad_norm=181.566879 penalty=19.457678 soft_support=19.458 expected_select=7.700 suspect_number=1
# [epoch 2600] loss=243.171463 tau=0.273114 grad_norm=178.532669 penalty=19.411537 soft_support=19.412 expected_select=7.710 suspect_number=1
# [epoch 2700] loss=243.195068 tau=0.259810 grad_norm=207.435272 penalty=19.771784 soft_support=19.772 expected_select=8.000 suspect_number=0
# [epoch 2800] loss=243.047958 tau=0.247154 grad_norm=176.005386 penalty=19.989611 soft_support=19.990 expected_select=8.230 suspect_number=0
# [epoch 2900] loss=243.186462 tau=0.235115 grad_norm=176.220490 penalty=20.497475 soft_support=20.497 expected_select=8.480 suspect_number=1
# [epoch 3000] loss=243.015167 tau=0.223663 grad_norm=135.915527 penalty=21.298073 soft_support=21.298 expected_select=8.970 suspect_number=0
# [epoch 3100] loss=243.212067 tau=0.212768 grad_norm=83.962517 penalty=21.910946 soft_support=21.911 expected_select=9.150 suspect_number=0
# [epoch 3200] loss=242.982864 tau=0.202404 grad_norm=236.486008 penalty=21.899263 soft_support=21.899 expected_select=9.180 suspect_number=0
# [epoch 3300] loss=243.002792 tau=0.192544 grad_norm=240.699600 penalty=21.689789 soft_support=21.690 expected_select=9.190 suspect_number=0
# [epoch 3400] loss=243.043823 tau=0.183165 grad_norm=271.331207 penalty=21.588184 soft_support=21.588 expected_select=9.070 suspect_number=0
# [epoch 3500] loss=242.931168 tau=0.174243 grad_norm=250.073486 penalty=21.579716 soft_support=21.580 expected_select=9.070 suspect_number=0
# [epoch 3600] loss=242.839539 tau=0.165756 grad_norm=304.178833 penalty=21.528492 soft_support=21.528 expected_select=9.270 suspect_number=0
# [epoch 3700] loss=242.876602 tau=0.157682 grad_norm=332.492065 penalty=21.592190 soft_support=21.592 expected_select=9.530 suspect_number=0
# [epoch 3800] loss=242.948029 tau=0.150001 grad_norm=355.551270 penalty=21.696815 soft_support=21.697 expected_select=9.760 suspect_number=1
# [epoch 3900] loss=242.908646 tau=0.142694 grad_norm=403.416809 penalty=21.837526 soft_support=21.838 expected_select=10.210 suspect_number=0
# [epoch 4000] loss=243.003479 tau=0.135743 grad_norm=408.724091 penalty=21.967646 soft_support=21.968 expected_select=10.590 suspect_number=1
# [epoch 4100] loss=242.863983 tau=0.129131 grad_norm=437.772858 penalty=22.007420 soft_support=22.007 expected_select=10.820 suspect_number=1
# [epoch 4200] loss=242.875885 tau=0.122841 grad_norm=470.511719 penalty=22.260441 soft_support=22.260 expected_select=11.030 suspect_number=0
# [epoch 4300] loss=242.871246 tau=0.116858 grad_norm=461.778961 penalty=22.389505 soft_support=22.390 expected_select=11.230 suspect_number=1
# [epoch 4400] loss=242.921494 tau=0.111165 grad_norm=451.328979 penalty=22.657291 soft_support=22.657 expected_select=11.790 suspect_number=0
# [epoch 4500] loss=243.055420 tau=0.105750 grad_norm=207.126450 penalty=24.655350 soft_support=24.655 expected_select=12.990 suspect_number=0
# [epoch 4600] loss=242.826569 tau=0.100599 grad_norm=372.864441 penalty=24.498507 soft_support=24.499 expected_select=13.020 suspect_number=0
# [epoch 4700] loss=242.882278 tau=0.095699 grad_norm=445.225220 penalty=24.437660 soft_support=24.438 expected_select=13.000 suspect_number=0
# [epoch 4800] loss=242.776077 tau=0.091037 grad_norm=451.267426 penalty=24.551121 soft_support=24.551 expected_select=13.000 suspect_number=0
# [epoch 4900] loss=242.831345 tau=0.086603 grad_norm=486.215759 penalty=24.601755 soft_support=24.602 expected_select=13.060 suspect_number=0
# [epoch 5000] loss=242.854919 tau=0.082384 grad_norm=506.939453 penalty=24.712036 soft_support=24.712 expected_select=13.150 suspect_number=0
# [epoch 5100] loss=242.830215 tau=0.078371 grad_norm=561.378479 penalty=25.006163 soft_support=25.006 expected_select=13.440 suspect_number=1
# [epoch 5200] loss=242.840591 tau=0.074554 grad_norm=605.064209 penalty=25.130049 soft_support=25.130 expected_select=13.960 suspect_number=0
# [epoch 5300] loss=242.738037 tau=0.070922 grad_norm=597.640076 penalty=25.428213 soft_support=25.428 expected_select=14.540 suspect_number=1
# [epoch 5400] loss=242.866058 tau=0.067468 grad_norm=500.927094 penalty=25.940613 soft_support=25.941 expected_select=15.070 suspect_number=0
# [epoch 5500] loss=243.028122 tau=0.064181 grad_norm=308.184052 penalty=27.803766 soft_support=27.804 expected_select=18.870 suspect_number=2
# [epoch 5600] loss=242.845154 tau=0.061055 grad_norm=481.434143 penalty=28.522116 soft_support=28.522 expected_select=19.970 suspect_number=0
# [epoch 5700] loss=242.733597 tau=0.058081 grad_norm=544.588257 penalty=28.432650 soft_support=28.433 expected_select=19.900 suspect_number=0
# [epoch 5800] loss=242.769562 tau=0.055252 grad_norm=618.722351 penalty=28.451693 soft_support=28.452 expected_select=19.890 suspect_number=0
# [epoch 5900] loss=242.894867 tau=0.052560 grad_norm=634.251221 penalty=28.503836 soft_support=28.504 expected_select=19.870 suspect_number=0
# [epoch 6000] loss=242.800476 tau=0.050000 grad_norm=643.316528 penalty=28.690779 soft_support=28.691 expected_select=19.970 suspect_number=0
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'snr': 2.5, 'active_idx': [14, 23, 24, 28, 29, 45, 69, 74, 84, 90]}
#
# ===== Training / penalty config =====
# {'penalty_type': 'support_l1', 'penalty_weight': 0.001, 'support_target': None, 'tau_end': 0.05, 'anneal_ratio': 1}
#
# ===== Variational PIP summary =====
# {'R': 100, 'pip_threshold': 0.9, 'expected_support_size': 19.860000610351562, 'n_selected_at_c': 20, 'selected_idx_at_c': [4, 5, 10, 14, 23, 24, 28, 29, 30, 33, 37, 45, 55, 56, 57, 64, 69, 86, 90, 93]}
#
# ===== Selection metrics at threshold c =====
# {'tp': 8, 'fp': 12, 'fn': 2, 'tn': 78, 'precision': 0.4, 'recall': 0.8, 'f1': 0.5333333333333333}
#
# ===== Top 20 variables by pip =====
#  j  pip  beta_hard_mean  is_true_active  beta_true
# 28 1.00       -2.509564            True  -1.759511
# 90 1.00       -1.395338            True  -1.979678
# 55 1.00       -0.277073           False   0.000000
# 64 1.00        1.166817           False   0.000000
# 45 1.00        0.587424            True   1.536880
# 69 1.00        1.371926            True   0.941051
# 37 1.00       -1.731380           False   0.000000
# 30 1.00        1.689582           False   0.000000
# 29 1.00        1.515665            True   0.670153
# 24 1.00       -0.945378            True  -0.703405
# 23 1.00       -1.107985            True  -1.340611
# 86 1.00       -1.943785           False   0.000000
# 14 1.00       -1.349001            True  -1.521852
# 56 1.00        1.395611           False   0.000000
#  5 1.00        0.724944           False   0.000000
#  4 1.00        2.089104           False   0.000000
# 10 1.00       -1.304288           False   0.000000
# 93 0.97       -1.465573           False   0.000000
# 57 0.96        1.613060           False   0.000000
# 33 0.93       -1.192894           False   0.000000

# %%
def plot_training_overview(out):
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    epochs = np.arange(1, len(out["losses"]) + 1)

    # panel A: loss
    axes[0, 0].plot(epochs, out["losses"])
    axes[0, 0].set_title("Training loss")
    axes[0, 0].set_xlabel("Epoch")
    axes[0, 0].set_ylabel("Loss")

    # panel B: tau
    axes[0, 1].plot(epochs, out["tau_hist"])
    axes[0, 1].set_title("Temperature path")
    axes[0, 1].set_xlabel("Epoch")
    axes[0, 1].set_ylabel("Tau")

    # panel C: expected support + suspect count
    if "expected_support_hist" in out:
        axes[1, 0].plot(epochs, out["expected_support_hist"], label="expected support")
        if "suspect_hist" in out:
            ax2 = axes[1, 0].twinx()
            ax2.plot(epochs, out["suspect_hist"], linestyle="--", label="suspect count")
            ax2.set_ylabel("Suspect count")
            lines1, labels1 = axes[1, 0].get_legend_handles_labels()
            lines2, labels2 = ax2.get_legend_handles_labels()
            axes[1, 0].legend(lines1 + lines2, labels1 + labels2, loc="best")
        axes[1, 0].set_title("Expected support and ambiguity")
        axes[1, 0].set_xlabel("Epoch")
        axes[1, 0].set_ylabel("Expected support size")
    else:
        axes[1, 0].text(0.5, 0.5, "expected_support_hist not stored",
                        ha="center", va="center", transform=axes[1, 0].transAxes)
        axes[1, 0].set_title("Expected support and ambiguity")

    # panel D: penalty + soft support
    has_pen = "penalty_hist" in out
    has_soft = "soft_support_hist" in out
    if has_pen or has_soft:
        if has_pen:
            axes[1, 1].plot(epochs, out["penalty_hist"], label="penalty")
        if has_soft:
            axes[1, 1].plot(epochs, out["soft_support_hist"], label="soft support")
        axes[1, 1].legend(loc="best")
        axes[1, 1].set_title("Penalty and soft support")
        axes[1, 1].set_xlabel("Epoch")
    else:
        axes[1, 1].text(0.5, 0.5, "penalty_hist / soft_support_hist not stored",
                        ha="center", va="center", transform=axes[1, 1].transAxes)
        axes[1, 1].set_title("Penalty and soft support")

    plt.tight_layout()
    return fig

def plot_pip_rank(out):
    pip_df = out["pip_df"].copy()
    sim_info = out["sim_info"]

    true_active = set(sim_info["active_idx"].tolist()) if hasattr(sim_info["active_idx"], "tolist") else set(sim_info["active_idx"])
    pip_df["is_true_active"] = pip_df["j"].isin(true_active)

    pip_df = pip_df.sort_values("pip", ascending=False).reset_index(drop=True)

    x = np.arange(len(pip_df))
    y = pip_df["pip"].to_numpy()
    mask_true = pip_df["is_true_active"].to_numpy()
    mask_null = ~mask_true

    fig, ax = plt.subplots(figsize=(10, 4))
    ax.scatter(x[mask_null], y[mask_null], s=20, label="Null")
    ax.scatter(x[mask_true], y[mask_true], s=30, label="Signal")

    c = out["pip_metrics"]["pip_threshold"]
    ax.axhline(c, linestyle="--", linewidth=1)

    ax.set_title("PIP ranking")
    ax.set_xlabel("Variables sorted by PIP")
    ax.set_ylabel("PIP")
    ax.legend(loc="best")

    plt.tight_layout()
    return fig

def plot_sut_posterior_summary(out, top_k=20, sort_by="pip"):
    draws = out["posterior_draws"]
    pip_df = out["pip_df"].copy()
    sim_info = out["sim_info"]

    s = draws["s"].cpu().numpy()   # [R, p]
    u = draws["u"].cpu().numpy()   # [R, p]
    t = draws["t"].cpu().numpy()   # [R, 1] or [R]

    if t.ndim == 2 and t.shape[1] == 1:
        t = t[:, 0]

    true_active = set(sim_info["active_idx"].tolist()) if hasattr(sim_info["active_idx"], "tolist") else set(sim_info["active_idx"])
    pip_df["is_true_active"] = pip_df["j"].isin(true_active)

    # posterior summaries
    pip_df["s_mean"] = s.mean(axis=0)
    pip_df["s_sd"] = s.std(axis=0)
    pip_df["u_mean"] = u.mean(axis=0)
    pip_df["u_sd"] = u.std(axis=0)

    if sort_by not in pip_df.columns:
        raise ValueError(f"sort_by='{sort_by}' not found in pip_df columns: {list(pip_df.columns)}")

    df_top = pip_df.sort_values(sort_by, ascending=False).head(top_k).copy()
    x = np.arange(len(df_top))

    fig, axes = plt.subplots(2, 2, figsize=(13, 9))

    # A. posterior of t
    axes[0, 0].hist(t, bins=40, density=True, alpha=0.8)
    axes[0, 0].axvline(np.mean(t), linestyle="--", linewidth=1)
    axes[0, 0].set_title("Posterior of threshold $t$")
    axes[0, 0].set_xlabel("$t$")
    axes[0, 0].set_ylabel("Density")

    # B. posterior mean +/- 2sd for s_j
    mask_true = df_top["is_true_active"].to_numpy()
    axes[0, 1].errorbar(
        x[~mask_true],
        df_top.loc[~mask_true, "s_mean"],
        yerr=2 * df_top.loc[~mask_true, "s_sd"],
        fmt="o",
        capsize=3,
        label="Null",
    )
    axes[0, 1].errorbar(
        x[mask_true],
        df_top.loc[mask_true, "s_mean"],
        yerr=2 * df_top.loc[mask_true, "s_sd"],
        fmt="o",
        capsize=3,
        label="Signal",
    )
    axes[0, 1].axhline(0.0, linestyle="--", linewidth=1)
    axes[0, 1].set_title(f"Posterior of $s_j$ (top {top_k} by {sort_by})")
    axes[0, 1].set_xlabel("Variables")
    axes[0, 1].set_ylabel("Mean ± 2sd")
    axes[0, 1].set_xticks(x)
    axes[0, 1].set_xticklabels(df_top["j"].astype(int).tolist(), rotation=90)
    axes[0, 1].legend(loc="best")

    # C. posterior mean +/- 2sd for u_j
    axes[1, 0].errorbar(
        x[~mask_true],
        df_top.loc[~mask_true, "u_mean"],
        yerr=2 * df_top.loc[~mask_true, "u_sd"],
        fmt="o",
        capsize=3,
        label="Null",
    )
    axes[1, 0].errorbar(
        x[mask_true],
        df_top.loc[mask_true, "u_mean"],
        yerr=2 * df_top.loc[mask_true, "u_sd"],
        fmt="o",
        capsize=3,
        label="Signal",
    )
    axes[1, 0].axhline(np.mean(t), linestyle="--", linewidth=1, label="mean(t)")
    axes[1, 0].set_title(f"Posterior of $u_j$ (top {top_k} by {sort_by})")
    axes[1, 0].set_xlabel("Variables")
    axes[1, 0].set_ylabel("Mean ± 2sd")
    axes[1, 0].set_xticks(x)
    axes[1, 0].set_xticklabels(df_top["j"].astype(int).tolist(), rotation=90)
    axes[1, 0].legend(loc="best")

    # D. u_mean vs s_mean scatter
    all_mask_true = pip_df["is_true_active"].to_numpy()
    axes[1, 1].scatter(
        pip_df.loc[~all_mask_true, "u_mean"],
        pip_df.loc[~all_mask_true, "s_mean"],
        s=20,
        label="Null",
    )
    axes[1, 1].scatter(
        pip_df.loc[all_mask_true, "u_mean"],
        pip_df.loc[all_mask_true, "s_mean"],
        s=30,
        label="Signal",
    )
    axes[1, 1].axvline(np.mean(t), linestyle="--", linewidth=1)
    axes[1, 1].axhline(0.0, linestyle="--", linewidth=1)
    axes[1, 1].set_title(r"Posterior means: $E[u_j]$ vs $E[s_j]$")
    axes[1, 1].set_xlabel(r"$E[u_j]$")
    axes[1, 1].set_ylabel(r"$E[s_j]$")
    axes[1, 1].legend(loc="best")

    plt.tight_layout()
    return fig

def get_selection_margin_draws(out):
    draws = out["posterior_draws"]
    u = draws["u"]   # [R, p]
    t = draws["t"]   # [R, 1] or [R]

    if t.ndim == 1:
        t = t.unsqueeze(1)

    m = (u - t).cpu().numpy()   # [R, p]
    return m

def choose_selection_density_indices(out, n_signal=2, n_null=3):
    pip_df = out["pip_df"].copy()
    sim_info = out["sim_info"]

    true_active = set(sim_info["active_idx"].tolist()) if hasattr(sim_info["active_idx"], "tolist") else set(sim_info["active_idx"])
    pip_df["is_true_active"] = pip_df["j"].isin(true_active)

    # 选高 PIP 的真 signal
    signal_idx = (
        pip_df[pip_df["is_true_active"]]
        .sort_values("pip", ascending=False)["j"]
        .tolist()[:n_signal]
    )

    # 选低 PIP 的 null
    null_idx = (
        pip_df[~pip_df["is_true_active"]]
        .sort_values("pip", ascending=True)["j"]
        .tolist()[:n_null]
    )

    return signal_idx, null_idx

def plot_selection_density(
    out,
    signal_idx=None,
    null_idx=None,
    bins=70,
    xlim=None,
    title="Posterior of selection margins",
):
    m = get_selection_margin_draws(out)   # [R, p]

    if signal_idx is None or null_idx is None:
        auto_signal, auto_null = choose_selection_density_indices(out, n_signal=2, n_null=3)
        if signal_idx is None:
            signal_idx = auto_signal
        if null_idx is None:
            null_idx = auto_null

    fig, ax = plt.subplots(figsize=(8, 5))

    # signals
    for k, j in enumerate(signal_idx):
        ax.hist(
            m[:, j],
            bins=bins,
            density=True,
            histtype="step",
            linewidth=2,
            label=f"signal {j}",
        )

    # nulls
    for k, j in enumerate(null_idx):
        ax.hist(
            m[:, j],
            bins=bins,
            density=True,
            histtype="step",
            linewidth=2,
            label=f"null {j}",
        )

    ax.axvline(0.0, linestyle="--", linewidth=1.5)
    ax.set_title(title)
    ax.set_xlabel(r"$m_j = u_j - t$")
    ax.set_ylabel("density")
    ax.legend(loc="best")

    if xlim is not None:
        ax.set_xlim(xlim)

    plt.tight_layout()
    return fig

# %%
plot_training_overview(out_flow1); plt.show()
plot_pip_rank(out_flow1); plt.show()

plot_sut_posterior_summary(out_flow1, top_k=20, sort_by="pip")
plt.show()

plot_selection_density(out_flow1)
plt.show()

# %%
out_flow2 = simflow(
    seed=123,
    n=120,
    p=100,
    snr=2.5,
    true_prop=0.1,
    pip_R=100,
    pip_c=0.9,
    tau_end=0.1,
    anneal_ratio=0.8,
    K_q=16,
    K_g=16,
    hidden_units=64,
    num_hidden_layers=2,
    epochs=6000,
    num_samples=128,
    lr=5e-5,
    grad_clip=3.0,
    print_every=100,
    penalty_type="support_l1",
    penalty_weight=0.1, 
)

top_df2 = show_simflow_results(out_flow2, top_k=20, sort_by="pip")
# Out:
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'sigma2': 6.834272766113282, 'sigma': 2.614244205523516, 'active_idx': array([14, 23, 24, 28, 29, 45, 69, 74, 84, 90], dtype=int64), 'snr': 2.5}
# [epoch 0001] loss=896.778076 tau=1.000000 grad_norm=275.916473 penalty=50.135815 soft_support=50.136 expected_select=45.730 suspect_number=100
# [epoch 0100] loss=661.344727 tau=0.953610 grad_norm=190.965134 penalty=63.036144 soft_support=63.036 expected_select=73.760 suspect_number=6
# [epoch 0200] loss=375.505310 tau=0.908935 grad_norm=175.297318 penalty=21.389917 soft_support=21.390 expected_select=8.690 suspect_number=2
# [epoch 0300] loss=289.296173 tau=0.866354 grad_norm=155.388611 penalty=14.447495 soft_support=14.447 expected_select=4.300 suspect_number=0
# [epoch 0400] loss=265.725677 tau=0.825767 grad_norm=372.596008 penalty=10.682606 soft_support=10.683 expected_select=4.000 suspect_number=0
# [epoch 0500] loss=259.445770 tau=0.787082 grad_norm=169.585510 penalty=8.137993 soft_support=8.138 expected_select=4.000 suspect_number=0
# [epoch 0600] loss=257.423828 tau=0.750209 grad_norm=383.607025 penalty=7.380755 soft_support=7.381 expected_select=4.000 suspect_number=0
# [epoch 0700] loss=257.528137 tau=0.715064 grad_norm=859.040955 penalty=7.020406 soft_support=7.020 expected_select=4.000 suspect_number=0
# [epoch 0800] loss=254.509552 tau=0.681565 grad_norm=319.285706 penalty=6.482501 soft_support=6.483 expected_select=4.000 suspect_number=0
# [epoch 0900] loss=254.462830 tau=0.649635 grad_norm=540.803101 penalty=6.067639 soft_support=6.068 expected_select=4.000 suspect_number=0
# [epoch 1000] loss=253.008011 tau=0.619201 grad_norm=919.012268 penalty=5.649270 soft_support=5.649 expected_select=3.010 suspect_number=0
# [epoch 1100] loss=252.659363 tau=0.590193 grad_norm=843.679993 penalty=5.273203 soft_support=5.273 expected_select=3.000 suspect_number=0
# [epoch 1200] loss=252.155914 tau=0.562544 grad_norm=1371.116699 penalty=5.102895 soft_support=5.103 expected_select=3.000 suspect_number=0
# [epoch 1300] loss=251.516449 tau=0.536190 grad_norm=1164.619629 penalty=5.004614 soft_support=5.005 expected_select=3.000 suspect_number=0
# [epoch 1400] loss=252.339233 tau=0.511071 grad_norm=1570.880859 penalty=5.138267 soft_support=5.138 expected_select=3.000 suspect_number=0
# [epoch 1500] loss=251.966248 tau=0.487128 grad_norm=3356.107910 penalty=4.937152 soft_support=4.937 expected_select=3.000 suspect_number=0
# [epoch 1600] loss=251.310959 tau=0.464307 grad_norm=1042.203979 penalty=4.823076 soft_support=4.823 expected_select=3.000 suspect_number=0
# [epoch 1700] loss=249.841919 tau=0.442556 grad_norm=931.404175 penalty=4.753546 soft_support=4.754 expected_select=3.000 suspect_number=0
# [epoch 1800] loss=250.979492 tau=0.421823 grad_norm=1408.020630 penalty=4.652035 soft_support=4.652 expected_select=3.000 suspect_number=0
# [epoch 1900] loss=250.520004 tau=0.402062 grad_norm=1640.426392 penalty=4.620842 soft_support=4.621 expected_select=3.000 suspect_number=0
# [epoch 2000] loss=251.249512 tau=0.383226 grad_norm=2042.402466 penalty=4.611862 soft_support=4.612 expected_select=3.000 suspect_number=0
# [epoch 2100] loss=250.491089 tau=0.365273 grad_norm=2039.313354 penalty=4.658241 soft_support=4.658 expected_select=3.000 suspect_number=0
# [epoch 2200] loss=250.081711 tau=0.348161 grad_norm=1969.027954 penalty=4.543693 soft_support=4.544 expected_select=3.000 suspect_number=0
# [epoch 2300] loss=249.508026 tau=0.331850 grad_norm=2185.225098 penalty=4.570875 soft_support=4.571 expected_select=3.000 suspect_number=0
# [epoch 2400] loss=250.071655 tau=0.316304 grad_norm=2461.567383 penalty=4.592698 soft_support=4.593 expected_select=3.000 suspect_number=0
# [epoch 2500] loss=249.568619 tau=0.301486 grad_norm=2102.061279 penalty=4.554907 soft_support=4.555 expected_select=3.000 suspect_number=0
# [epoch 2600] loss=248.919586 tau=0.287362 grad_norm=2154.465332 penalty=4.475675 soft_support=4.476 expected_select=3.000 suspect_number=0
# [epoch 2700] loss=248.864151 tau=0.273899 grad_norm=2679.311279 penalty=4.479280 soft_support=4.479 expected_select=3.000 suspect_number=0
# [epoch 2800] loss=249.173752 tau=0.261068 grad_norm=3257.699707 penalty=4.473389 soft_support=4.473 expected_select=3.000 suspect_number=0
# [epoch 2900] loss=248.889786 tau=0.248837 grad_norm=4279.421387 penalty=4.518499 soft_support=4.518 expected_select=3.000 suspect_number=0
# [epoch 3000] loss=248.592529 tau=0.237180 grad_norm=2571.597656 penalty=4.819605 soft_support=4.820 expected_select=3.000 suspect_number=0
# [epoch 3100] loss=249.570923 tau=0.226069 grad_norm=2878.933594 penalty=4.660887 soft_support=4.661 expected_select=3.000 suspect_number=0
# [epoch 3200] loss=248.780029 tau=0.215478 grad_norm=3125.620117 penalty=4.602375 soft_support=4.602 expected_select=3.000 suspect_number=0
# [epoch 3300] loss=248.442047 tau=0.205383 grad_norm=3055.220703 penalty=4.593808 soft_support=4.594 expected_select=3.000 suspect_number=0
# [epoch 3400] loss=248.365356 tau=0.195762 grad_norm=3423.267334 penalty=4.586944 soft_support=4.587 expected_select=3.000 suspect_number=0
# [epoch 3500] loss=248.422211 tau=0.186591 grad_norm=3899.331787 penalty=4.596292 soft_support=4.596 expected_select=3.000 suspect_number=0
# [epoch 3600] loss=247.940109 tau=0.177849 grad_norm=3852.106934 penalty=4.594296 soft_support=4.594 expected_select=3.000 suspect_number=0
# [epoch 3700] loss=248.094238 tau=0.169517 grad_norm=4570.076172 penalty=4.624005 soft_support=4.624 expected_select=3.000 suspect_number=0
# [epoch 3800] loss=248.183426 tau=0.161576 grad_norm=4088.273926 penalty=4.642608 soft_support=4.643 expected_select=3.000 suspect_number=0
# [epoch 3900] loss=248.282623 tau=0.154007 grad_norm=4891.341309 penalty=4.683102 soft_support=4.683 expected_select=3.000 suspect_number=0
# [epoch 4000] loss=248.047089 tau=0.146792 grad_norm=4830.489258 penalty=4.689965 soft_support=4.690 expected_select=3.000 suspect_number=0
# [epoch 4100] loss=248.122620 tau=0.139915 grad_norm=5767.310547 penalty=4.693267 soft_support=4.693 expected_select=3.000 suspect_number=0
# [epoch 4200] loss=247.953262 tau=0.133360 grad_norm=5591.911133 penalty=4.761032 soft_support=4.761 expected_select=3.000 suspect_number=0
# [epoch 4300] loss=248.045883 tau=0.127113 grad_norm=6015.512695 penalty=4.739050 soft_support=4.739 expected_select=3.000 suspect_number=0
# [epoch 4400] loss=247.980881 tau=0.121158 grad_norm=6402.248047 penalty=4.730905 soft_support=4.731 expected_select=3.000 suspect_number=0
# [epoch 4500] loss=247.982178 tau=0.115482 grad_norm=7097.024902 penalty=4.819674 soft_support=4.820 expected_select=3.000 suspect_number=0
# [epoch 4600] loss=247.648148 tau=0.110072 grad_norm=7410.126465 penalty=4.777867 soft_support=4.778 expected_select=3.000 suspect_number=0
# [epoch 4700] loss=247.954346 tau=0.104915 grad_norm=7185.872070 penalty=4.917542 soft_support=4.918 expected_select=3.000 suspect_number=0
# [epoch 4800] loss=247.955124 tau=0.100000 grad_norm=8131.666016 penalty=4.906742 soft_support=4.907 expected_select=3.000 suspect_number=0
# [epoch 4900] loss=247.915405 tau=0.100000 grad_norm=10370.006836 penalty=4.915528 soft_support=4.916 expected_select=3.000 suspect_number=0
# [epoch 5000] loss=247.827606 tau=0.100000 grad_norm=8220.422852 penalty=4.927288 soft_support=4.927 expected_select=3.000 suspect_number=0
# [epoch 5100] loss=247.737015 tau=0.100000 grad_norm=6920.301270 penalty=4.962441 soft_support=4.962 expected_select=3.000 suspect_number=0
# [epoch 5200] loss=247.845810 tau=0.100000 grad_norm=8102.358887 penalty=4.988757 soft_support=4.989 expected_select=3.000 suspect_number=0
# [epoch 5300] loss=247.597046 tau=0.100000 grad_norm=7529.962891 penalty=5.022445 soft_support=5.022 expected_select=3.000 suspect_number=0
# [epoch 5400] loss=247.887985 tau=0.100000 grad_norm=6748.438477 penalty=5.039076 soft_support=5.039 expected_select=3.000 suspect_number=0
# [epoch 5500] loss=247.637314 tau=0.100000 grad_norm=5498.627441 penalty=5.143615 soft_support=5.144 expected_select=3.000 suspect_number=0
# [epoch 5600] loss=248.058197 tau=0.100000 grad_norm=4393.276367 penalty=5.641014 soft_support=5.641 expected_select=3.000 suspect_number=0
# [epoch 5700] loss=247.484329 tau=0.100000 grad_norm=3969.999023 penalty=5.314430 soft_support=5.314 expected_select=3.000 suspect_number=0
# [epoch 5800] loss=252.884552 tau=0.100000 grad_norm=13256.817383 penalty=5.368511 soft_support=5.369 expected_select=3.000 suspect_number=0
# [epoch 5900] loss=247.657150 tau=0.100000 grad_norm=2994.453857 penalty=5.647573 soft_support=5.648 expected_select=3.000 suspect_number=0
# [epoch 6000] loss=247.839462 tau=0.100000 grad_norm=988.803772 penalty=5.639210 soft_support=5.639 expected_select=3.000 suspect_number=0
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'snr': 2.5, 'active_idx': [14, 23, 24, 28, 29, 45, 69, 74, 84, 90]}
#
# ===== Training / penalty config =====
# {'penalty_type': 'support_l1', 'penalty_weight': 0.1, 'support_target': None, 'tau_end': 0.1, 'anneal_ratio': 0.8}
#
# ===== Variational PIP summary =====
# {'R': 100, 'pip_threshold': 0.9, 'expected_support_size': 3.0, 'n_selected_at_c': 3, 'selected_idx_at_c': [14, 28, 90]}
#
# ===== Selection metrics at threshold c =====
# {'tp': 3, 'fp': 0, 'fn': 7, 'tn': 90, 'precision': 1.0, 'recall': 0.3, 'f1': 0.4615384615384615}
#
# ===== Top 20 variables by pip =====
#  j  pip  beta_hard_mean  is_true_active  beta_true
# 28  1.0       -2.315635            True  -1.759511
# 14  1.0       -1.214424            True  -1.521852
# 90  1.0       -1.640800            True  -1.979678
# 73  0.0        0.000000           False   0.000000
# 72  0.0        0.000000           False   0.000000
# 71  0.0        0.000000           False   0.000000
# 70  0.0        0.000000           False   0.000000
# 69  0.0        0.000000            True   0.941051
# 68  0.0        0.000000           False   0.000000
# 67  0.0        0.000000           False   0.000000
# 66  0.0        0.000000           False   0.000000
# 65  0.0        0.000000           False   0.000000
# 64  0.0        0.000000           False   0.000000
#  0  0.0        0.000000           False   0.000000
# 74  0.0        0.000000            True   1.029608
# 62  0.0        0.000000           False   0.000000
# 61  0.0        0.000000           False   0.000000
# 60  0.0        0.000000           False   0.000000
# 59  0.0        0.000000           False   0.000000
# 58  0.0        0.000000           False   0.000000

# %%
out_flow3 = simflow(
    seed=123,
    n=120,
    p=100,
    snr=2.5,
    true_prop=0.1,
    pip_R=100,
    pip_c=0.9,
    tau_end=0.1,
    anneal_ratio=0.8,
    K_q=16,
    K_g=16,
    hidden_units=64,
    num_hidden_layers=2,
    epochs=6000,
    num_samples=128,
    lr=5e-5,
    grad_clip=3.0,
    print_every=100,
    penalty_type="support_l1",
    penalty_weight=0.01, 
)

top_df3 = show_simflow_results(out_flow3, top_k=20, sort_by="pip")
# Out:
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'sigma2': 6.834272766113282, 'sigma': 2.614244205523516, 'active_idx': array([14, 23, 24, 28, 29, 45, 69, 74, 84, 90], dtype=int64), 'snr': 2.5}
# [epoch 0001] loss=892.265808 tau=1.000000 grad_norm=275.484558 penalty=50.135815 soft_support=50.136 expected_select=45.890 suspect_number=100
# [epoch 0100] loss=655.224182 tau=0.953610 grad_norm=189.170731 penalty=69.855583 soft_support=69.856 expected_select=86.490 suspect_number=6
# [epoch 0200] loss=378.542664 tau=0.908935 grad_norm=117.432556 penalty=30.813082 soft_support=30.813 expected_select=16.920 suspect_number=13
# [epoch 0300] loss=289.838837 tau=0.866354 grad_norm=79.360687 penalty=24.803608 soft_support=24.804 expected_select=9.890 suspect_number=3
# [epoch 0400] loss=263.222321 tau=0.825767 grad_norm=95.459984 penalty=21.215443 soft_support=21.215 expected_select=7.180 suspect_number=0
# [epoch 0500] loss=254.725632 tau=0.787082 grad_norm=104.118439 penalty=19.294609 soft_support=19.295 expected_select=6.010 suspect_number=2
# [epoch 0600] loss=250.793106 tau=0.750209 grad_norm=90.868851 penalty=17.259470 soft_support=17.259 expected_select=4.850 suspect_number=0
# [epoch 0700] loss=249.793579 tau=0.715064 grad_norm=59.687012 penalty=15.583114 soft_support=15.583 expected_select=4.490 suspect_number=1
# [epoch 0800] loss=247.195312 tau=0.681565 grad_norm=172.179153 penalty=14.442419 soft_support=14.442 expected_select=4.220 suspect_number=0
# [epoch 0900] loss=247.059021 tau=0.649635 grad_norm=162.571091 penalty=13.391864 soft_support=13.392 expected_select=4.060 suspect_number=0
# [epoch 1000] loss=246.610809 tau=0.619201 grad_norm=145.193680 penalty=12.659101 soft_support=12.659 expected_select=4.010 suspect_number=0
# [epoch 1100] loss=246.305389 tau=0.590193 grad_norm=413.814880 penalty=12.185716 soft_support=12.186 expected_select=4.010 suspect_number=0
# [epoch 1200] loss=245.868896 tau=0.562544 grad_norm=262.933197 penalty=11.927999 soft_support=11.928 expected_select=4.000 suspect_number=0
# [epoch 1300] loss=245.233368 tau=0.536190 grad_norm=449.714661 penalty=11.565763 soft_support=11.566 expected_select=4.000 suspect_number=0
# [epoch 1400] loss=245.511734 tau=0.511071 grad_norm=410.375763 penalty=11.576811 soft_support=11.577 expected_select=4.010 suspect_number=0
# [epoch 1500] loss=245.095078 tau=0.487128 grad_norm=307.443787 penalty=11.617128 soft_support=11.617 expected_select=4.000 suspect_number=0
# [epoch 1600] loss=245.029266 tau=0.464307 grad_norm=587.588196 penalty=11.031685 soft_support=11.032 expected_select=4.000 suspect_number=0
# [epoch 1700] loss=244.455139 tau=0.442556 grad_norm=593.363708 penalty=10.916258 soft_support=10.916 expected_select=4.010 suspect_number=0
# [epoch 1800] loss=244.681915 tau=0.421823 grad_norm=702.253052 penalty=10.765331 soft_support=10.765 expected_select=4.000 suspect_number=0
# [epoch 1900] loss=244.551834 tau=0.402062 grad_norm=605.108398 penalty=10.852670 soft_support=10.853 expected_select=4.000 suspect_number=0
# [epoch 2000] loss=244.943283 tau=0.383226 grad_norm=345.587219 penalty=11.720280 soft_support=11.720 expected_select=4.030 suspect_number=0
# [epoch 2100] loss=244.619995 tau=0.365273 grad_norm=501.990692 penalty=11.638454 soft_support=11.638 expected_select=4.030 suspect_number=0
# [epoch 2200] loss=244.127686 tau=0.348161 grad_norm=756.646240 penalty=10.864493 soft_support=10.864 expected_select=4.000 suspect_number=0
# [epoch 2300] loss=244.217377 tau=0.331850 grad_norm=829.524841 penalty=10.845128 soft_support=10.845 expected_select=4.030 suspect_number=0
# [epoch 2400] loss=244.483124 tau=0.316304 grad_norm=718.776367 penalty=11.047333 soft_support=11.047 expected_select=4.020 suspect_number=0
# [epoch 2500] loss=244.143326 tau=0.301486 grad_norm=909.423218 penalty=10.928141 soft_support=10.928 expected_select=4.000 suspect_number=0
# [epoch 2600] loss=244.088318 tau=0.287362 grad_norm=920.724060 penalty=10.730505 soft_support=10.731 expected_select=4.010 suspect_number=0
# [epoch 2700] loss=244.100830 tau=0.273899 grad_norm=908.356750 penalty=11.014305 soft_support=11.014 expected_select=4.000 suspect_number=0
# [epoch 2800] loss=243.892105 tau=0.261068 grad_norm=891.410706 penalty=11.127134 soft_support=11.127 expected_select=4.010 suspect_number=0
# [epoch 2900] loss=244.039032 tau=0.248837 grad_norm=920.891541 penalty=11.215731 soft_support=11.216 expected_select=4.020 suspect_number=0
# [epoch 3000] loss=243.944290 tau=0.237180 grad_norm=731.558716 penalty=11.710713 soft_support=11.711 expected_select=4.060 suspect_number=0
# [epoch 3100] loss=244.387527 tau=0.226069 grad_norm=699.413147 penalty=12.865874 soft_support=12.866 expected_select=4.330 suspect_number=1
# [epoch 3200] loss=243.841415 tau=0.215478 grad_norm=545.328003 penalty=12.323285 soft_support=12.323 expected_select=4.150 suspect_number=0
# [epoch 3300] loss=243.851868 tau=0.205383 grad_norm=692.659546 penalty=11.833756 soft_support=11.834 expected_select=4.080 suspect_number=0
# [epoch 3400] loss=243.913132 tau=0.195762 grad_norm=589.306580 penalty=11.795667 soft_support=11.796 expected_select=4.040 suspect_number=0
# [epoch 3500] loss=243.749680 tau=0.186591 grad_norm=1291.217285 penalty=11.729296 soft_support=11.729 expected_select=4.020 suspect_number=0
# [epoch 3600] loss=243.602081 tau=0.177849 grad_norm=867.194153 penalty=11.700239 soft_support=11.700 expected_select=4.070 suspect_number=0
# [epoch 3700] loss=243.613892 tau=0.169517 grad_norm=1177.784424 penalty=11.775084 soft_support=11.775 expected_select=4.080 suspect_number=0
# [epoch 3800] loss=243.717361 tau=0.161576 grad_norm=1006.642944 penalty=11.902839 soft_support=11.903 expected_select=4.050 suspect_number=0
# [epoch 3900] loss=243.778564 tau=0.154007 grad_norm=802.171143 penalty=12.408609 soft_support=12.409 expected_select=4.280 suspect_number=0
# [epoch 4000] loss=243.950546 tau=0.146792 grad_norm=1017.181335 penalty=13.832908 soft_support=13.833 expected_select=5.000 suspect_number=0
# [epoch 4100] loss=243.658066 tau=0.139915 grad_norm=1180.416504 penalty=13.222019 soft_support=13.222 expected_select=5.000 suspect_number=0
# [epoch 4200] loss=243.602127 tau=0.133360 grad_norm=1272.586304 penalty=12.961747 soft_support=12.962 expected_select=4.990 suspect_number=0
# [epoch 4300] loss=243.634399 tau=0.127113 grad_norm=1406.451904 penalty=12.763335 soft_support=12.763 expected_select=4.980 suspect_number=0
# [epoch 4400] loss=243.672562 tau=0.121158 grad_norm=1352.893066 penalty=12.784937 soft_support=12.785 expected_select=5.000 suspect_number=0
# [epoch 4500] loss=243.695831 tau=0.115482 grad_norm=636.737793 penalty=13.940944 soft_support=13.941 expected_select=5.000 suspect_number=0
# [epoch 4600] loss=243.601257 tau=0.110072 grad_norm=1124.008911 penalty=14.681464 soft_support=14.681 expected_select=5.000 suspect_number=0
# [epoch 4700] loss=243.614670 tau=0.104915 grad_norm=739.544006 penalty=13.951326 soft_support=13.951 expected_select=5.000 suspect_number=0
# [epoch 4800] loss=243.527786 tau=0.100000 grad_norm=994.468567 penalty=13.892080 soft_support=13.892 expected_select=5.000 suspect_number=0
# [epoch 4900] loss=243.569366 tau=0.100000 grad_norm=1655.356201 penalty=13.760740 soft_support=13.761 expected_select=5.000 suspect_number=0
# [epoch 5000] loss=243.535263 tau=0.100000 grad_norm=1499.187012 penalty=13.690588 soft_support=13.691 expected_select=5.000 suspect_number=0
# [epoch 5100] loss=243.530396 tau=0.100000 grad_norm=1686.946899 penalty=13.751806 soft_support=13.752 expected_select=5.000 suspect_number=0
# [epoch 5200] loss=243.537308 tau=0.100000 grad_norm=1699.322144 penalty=13.631782 soft_support=13.632 expected_select=5.000 suspect_number=0
# [epoch 5300] loss=243.392532 tau=0.100000 grad_norm=1353.838745 penalty=13.612850 soft_support=13.613 expected_select=5.000 suspect_number=0
# [epoch 5400] loss=243.626831 tau=0.100000 grad_norm=1276.465210 penalty=13.818337 soft_support=13.818 expected_select=5.000 suspect_number=0
# [epoch 5500] loss=243.605270 tau=0.100000 grad_norm=673.702148 penalty=14.532892 soft_support=14.533 expected_select=5.000 suspect_number=0
# [epoch 5600] loss=243.651398 tau=0.100000 grad_norm=479.908630 penalty=15.258928 soft_support=15.259 expected_select=5.000 suspect_number=0
# [epoch 5700] loss=243.464813 tau=0.100000 grad_norm=1330.686279 penalty=14.936750 soft_support=14.937 expected_select=5.000 suspect_number=0
# [epoch 5800] loss=243.392273 tau=0.100000 grad_norm=1024.485107 penalty=14.349442 soft_support=14.349 expected_select=5.000 suspect_number=0
# [epoch 5900] loss=243.611633 tau=0.100000 grad_norm=1295.140991 penalty=14.030526 soft_support=14.031 expected_select=5.000 suspect_number=0
# [epoch 6000] loss=243.454880 tau=0.100000 grad_norm=1409.926636 penalty=13.861411 soft_support=13.861 expected_select=5.000 suspect_number=0
# ===== Simulation info =====
# {'n': 120, 'p': 100, 'n_active': 10, 'snr': 2.5, 'active_idx': [14, 23, 24, 28, 29, 45, 69, 74, 84, 90]}
#
# ===== Training / penalty config =====
# {'penalty_type': 'support_l1', 'penalty_weight': 0.01, 'support_target': None, 'tau_end': 0.1, 'anneal_ratio': 0.8}
#
# ===== Variational PIP summary =====
# {'R': 100, 'pip_threshold': 0.9, 'expected_support_size': 5.0, 'n_selected_at_c': 5, 'selected_idx_at_c': [14, 28, 29, 64, 90]}
#
# ===== Selection metrics at threshold c =====
# {'tp': 4, 'fp': 1, 'fn': 6, 'tn': 89, 'precision': 0.8, 'recall': 0.4, 'f1': 0.5333333333333333}
#
# ===== Top 20 variables by pip =====
#  j  pip  beta_hard_mean  is_true_active  beta_true
# 64  1.0        1.081400           False   0.000000
# 90  1.0       -1.369579            True  -1.979678
# 29  1.0        2.390692            True   0.670153
# 14  1.0       -1.421929            True  -1.521852
# 28  1.0       -2.465525            True  -1.759511
# 57  0.0        0.000000           False   0.000000
# 66  0.0        0.000000           False   0.000000
# 54  0.0        0.000000           False   0.000000
# 73  0.0        0.000000           False   0.000000
# 72  0.0        0.000000           False   0.000000
# 71  0.0        0.000000           False   0.000000
# 70  0.0        0.000000           False   0.000000
# 69  0.0        0.000000            True   0.941051
# 68  0.0        0.000000           False   0.000000
# 67  0.0        0.000000           False   0.000000
# 65  0.0        0.000000           False   0.000000
# 58  0.0        0.000000           False   0.000000
# 55  0.0        0.000000           False   0.000000
# 74  0.0        0.000000            True   1.029608
# 63  0.0        0.000000           False   0.000000
